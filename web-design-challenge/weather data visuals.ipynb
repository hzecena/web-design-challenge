# %%
#dependencies 
import os
import pandas as pd
#csv path
csv_path = os.path.join('Resources', 'cities.csv')
cities_csv = pd.read_csv(csv_path)
# create html table and save to file 
cities_csv.to_html('table.html', index=False, classes=['table', 'table-striped', 'table-hover'])

# %%
x_temp = cities_df['Lat']
y_temp = cities_df['Max Temp']
plt.scatter(x_temp, y_temp)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
date = dt.date.today()
plt.title("City Latitude v. Max Temperature " + "(" + str(date) + ")")
plt.savefig('assets/images/Fig1.png')

# %%
x_cloud = cities_df['Lat']
y_cloud = cities_df['Cloudiness']
plt.scatter(x_cloud, y_cloud)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
date = dt.date.today()
plt.title("City Latitude v. Cloudiness " + "(" + str(date) + ")")
plt.savefig('assets/images/Fig2.png')

# %%
x_wind = cities_df['Lat']
y_wind = cities_df['Wind Speed']
plt.scatter(x_wind, y_wind)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
date = dt.date.today()
plt.title("City Latitude v. Wind Speed " + "(" + str(date) + ")")
plt.savefig('assets/images/Fig3.png')

# %%
x_humid = cities_df['Lat']
y_humid = cities_df['Humidity']
plt.scatter(x_humid, y_humid)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
date = dt.date.today()
plt.title("City Latitude v. Humidity " + "(" + str(date) + ")")
plt.savefig('assets/images/Fig4.png')
